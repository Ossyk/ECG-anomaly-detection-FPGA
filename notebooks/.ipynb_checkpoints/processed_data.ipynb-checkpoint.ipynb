# %%
import numpy as np
import os

processed_data_dir = r"C:\Users\oussk\OneDrive\Desktop\02 y 02 s\Advanced Logic Design\ecg-project\data\processed"

X_train=np.load(os.path.join(processed_data_dir,"X_train.npy"))
y_train=np.load(os.path.join(processed_data_dir,"y_train.npy"))


print(X_train)
print(y_train)
# Out:
# [[-0.61064917 -0.6113879  -0.6114758  ... -0.6750347  -0.6838623
#   -0.6948652 ]
#  [-0.6249127  -0.6214878  -0.61883134 ... -0.6286778  -0.6108018
#   -0.59166   ]
#  [-0.6036079  -0.5993601  -0.5944252  ... -0.72342825 -0.71475667
#   -0.7052042 ]
#  ...
#  [-0.36069334 -0.35143802 -0.34005383 ... -0.3803765  -0.37541944
#   -0.3699753 ]
#  [-0.20273156 -0.20018835 -0.1963071  ... -0.4153158  -0.4039667
#   -0.39030495]
#  [-0.22133632 -0.21698888 -0.21218468 ... -0.3400759  -0.33535224
#   -0.32955503]]
# [1 0 1 ... 1 0 0]
