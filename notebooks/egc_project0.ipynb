# %%
# 1 imports
import wfdb, matplotlib.pyplot as plt, numpy as np
# 2 load one record
record = wfdb.rdrecord(r"C:\Users\oussk\OneDrive\Desktop\02 y 02 s\Advanced Logic Design\ecg-project\data\raw\100")
length=2


# 3 plot ecg waveform
plt.plot(record.p_signal[:2000,0])

# 4. Preprocessing (prototype)

# 5. Inspect annotations
annotation= wfdb.rdann(r"C:\Users\oussk\OneDrive\Desktop\02 y 02 s\Advanced Logic Design\ecg-project\data\raw\100", 'atr')
print("Signal shape:", record.p_signal.shape)  # (n_samples, n_channels)
print("Sampling rate:", record.fs, "Hz")	
print("First 10 annotations:", annotation.symbol[:10]) #(N = normal, V = ventricular ectopic, etc.).
print("First 10 sample positions:", annotation.sample[:10])
# 6. Save or prepare for ML
# Out:
# Signal shape: (650000, 2)
# Sampling rate: 360 Hz
# First 10 annotations: ['+', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'A', 'N']
# First 10 sample positions: [  18   77  370  662  946 1231 1515 1809 2044 2402]
